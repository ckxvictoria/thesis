# %%
pip install requests beautifulsoup4 pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.0 MB/s eta 0:00:01
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 10.2 MB/s eta 0:00:01
# Collecting pandas
#   Downloading pandas-2.2.2-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 815 kB/s eta 0:00:01    |███                             | 1.1 MB 1.3 MB/s eta 0:00:09
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp39-cp39-macosx_11_0_arm64.whl (120 kB)
#      |████████████████████████████████| 120 kB 4.6 MB/s eta 0:00:01
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 2.5 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 2.7 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 5.8 MB/s  eta 0:00:01
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/victoriachen/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Collecting numpy>=1.22.4
#   Downloading numpy-2.0.0-cp39-cp39-macosx_14_0_arm64.whl (5.2 MB)
#      |████████████████████████████████| 5.2 MB 446 kB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      |████████████████████████████████| 505 kB 323 kB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      |████████████████████████████████| 345 kB 1.0 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Installing collected packages: urllib3, tzdata, soupsieve, pytz, numpy, idna, charset-normalizer, certifi, requests, pandas, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.3 certifi-2024.7.4 charset-normalizer-3.3.2 idna-3.7 numpy-2.0.0 pandas-2.2.2 pytz-2024.1 requests-2.32.3 soupsieve-2.5 tzdata-2024.1 urllib3-2.2.2
# WARNING: You are using pip version 21.2.4; however, version 24.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urljoin
# Out:
# /Users/victoriachen/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Set folder where to save the dataset and HTML files
folder_dataset = os.path.expanduser("~/Downloads/test/dataset/")
folder_html_files = os.path.expanduser("~/Downloads/test/html_files/")
os.makedirs(folder_dataset, exist_ok=True)
os.makedirs(folder_html_files, exist_ok=True)

# Set URL of the main webpage to scrape
# Read the CSV file into a DataFrame
df = pd.read_csv('/users/victoriachen/Documents/My Baby Thesis/libraries_in_london.csv')

# Get the rows and convert it to a string
urls = df['urls'].iloc[0:3].tolist()

print(urls)
# Out:
# ['https://www.vwml.org/', 'http://www.wellcomecollection.org', 'https://www.lambeth.gov.uk/libraries-0/carnegie-library']

# %%
index=0
while index< len(urls):
    start_url=urls[index]

    # Initialize dataset
    website = pd.DataFrame({
        'url_relative': ["__index__"],  # relative url from links
        'url_absolute': [start_url],    # absolute url
        'retrieved': [False],           # whether the page has been retrieved or not
        'page_html': [None],            # file where the HTML content has been saved
        'page_text': [None]             # text from the page paragraphs
    })

    # Function to clean and generate filename for HTML
    def generate_filename(url):
        return os.path.join(folder_html_files,
                            url.replace("http://", "").replace("https://", "")
                               .replace("/", "_").replace(".", "_")
                               .replace("#", "_").replace("-", "_") + ".html")

    # Function to scrape webpage
    def scrape_page(url):
        response = requests.get(url)
        if response.status_code == 200:
            return response.text
        else:
            return None

    website['filename'] = website['url_absolute'].apply(generate_filename)

    website_flag=-1
    while not website[website['retrieved'] == False].empty:
        current_url = website.loc[website['retrieved'] == False, 'url_absolute'].values[0]
        current_url_filename = generate_filename(current_url)

        if(website_flag==len(website[website['retrieved'] == True])):
            break
        else:
            website_flag=-1

        # Keep track while retrieving pages
        print(f"{len(website[website['retrieved'] == True])} / {len(website)} done, working on {current_url}")

        website_flag=len(website[website['retrieved'] == True])

        # Retrieve and parse webpage at start url
        html_content = scrape_page(current_url)

        if html_content:
            # Save HTML content to file
            with open(current_url_filename, 'w', encoding='utf-8') as file:
                file.write(html_content)

            # Extract text
            soup = BeautifulSoup(html_content, 'html.parser')
            page_text = "\n\n".join([p.get_text() for p in soup.find_all('p')])

            # Update the current page content in the dataset
            website.loc[website['url_absolute'] == current_url, 'page_html'] = current_url_filename
            website.loc[website['url_absolute'] == current_url, 'page_text'] = page_text
            website.loc[website['url_absolute'] == current_url, 'retrieved'] = True

            # Extracting all links
            links = [a.get('href') for a in soup.find_all('a', href=True)]
            links = [link for link in links if link and not link.startswith(('mailto:', 'tel:', '#', '/#'))]
            links = [urljoin(start_url, link) if not link.startswith(('http://', 'https://')) else link for link in links]
            links = list(set(filter(lambda x: x.startswith(start_url), links)))

            # Add new links to the dataset
            new_links = pd.DataFrame({'url_relative': links, 'url_absolute': links})
            new_links['retrieved'] = False
            new_links['page_html'] = None
            new_links['page_text'] = None

            website = pd.concat([website, new_links]).drop_duplicates(subset=['url_absolute']).reset_index(drop=True)

    # Save dataset to CSV and RDS (using pickle for RDS equivalent)
    csv_filename = os.path.join(folder_dataset,
                                current_url.replace("http://", "").replace("https://", "").replace("/", "_").replace(".",
                                                                                                                     "_").replace(
                                    "#", "_").replace("-", "_") + ".csv")
    website.to_csv(csv_filename, index=False)

    rds_filename = os.path.join(folder_dataset,
                                current_url.replace("http://", "").replace("https://", "").replace("/", "_").replace(".",
                                                                                                                     "_").replace(
                                    "#", "_").replace("-", "_") + ".pkl")
    website.to_pickle(rds_filename)

    print("... DONE!")

    index=index+1
# Out:
# 0 / 1 done, working on https://www.vwml.org/
# 1 / 67 done, working on https://www.vwml.org/account
# 2 / 68 done, working on https://www.vwml.org/vwml-about-us/history-and-collections
# 3 / 70 done, working on https://www.vwml.org/vwml-catalogues-and-indexes/vwml-help/general-help
# 4 / 71 done, working on https://www.vwml.org/about-us/what-we-do/news/13732-new-vwml-website-set-to-launch
# 5 / 72 done, working on https://www.vwml.org/vwml-subject-guides/beginners-guide-music
# 6 / 73 done, working on https://www.vwml.org/vwml-digitised-resources/cecil-sharps-photographs
# 7 / 74 done, working on https://www.vwml.org/policies
# 8 / 190 done, working on https://www.vwml.org/vwml-events/past-events/past-special-conferences
# 9 / 191 done, working on https://www.vwml.org/vwml-catalogues-and-indexes/vwml-help/vwml-indexes-help
# 10 / 192 done, working on https://www.vwml.org/about-us/what-we-do/news/13637-exhibition-celebrates-cecil-sharps-singers
# 11 / 193 done, working on https://www.vwml.org/vwml-digitised-resources/cecil-sharps-appalachian-diaries
# 12 / 194 done, working on https://www.vwml.org/catalogues-indexes
# 13 / 195 done, working on https://www.vwml.org/vwml-about-us/services
# 14 / 202 done, working on https://www.vwml.org/travel-to-cecil-sharp-house
# 15 / 203 done, working on https://www.vwml.org/search?f=2
# 16 / 203 done, working on https://www.vwml.org/vwml-events/current-events
# 17 / 204 done, working on https://www.vwml.org/learning/young-people/national-youth-folk-ensemble
# 18 / 205 done, working on https://www.vwml.org/vwml-events/current-events/vwml-current-broadside-day
# 19 / 206 done, working on https://www.vwml.org/vwml-events/current-events/vwml-conference-current
# 20 / 207 done, working on https://www.vwml.org/use-of-cookies
# 21 / 208 done, working on https://www.vwml.org/vwml-about-us/planning-a-visit
# 22 / 216 done, working on https://www.vwml.org/vwml-catalogues-and-indexes/vwml-help/global-search-help
# 23 / 217 done, working on https://www.vwml.org/cdn-cgi/l/email-protection
# 24 / 217 done, working on https://www.vwml.org/vwml-catalogues-and-indexes/vwml-help/vwml-song-subject-index-help
# 25 / 218 done, working on https://www.vwml.org/vwml-events
# 26 / 219 done, working on https://www.vwml.org/vwml-about-us/vwml-projects
# 27 / 220 done, working on https://www.vwml.org/vwml-events/past-events/past-tunes-conferences
# 28 / 221 done, working on https://www.vwml.org/cdn-cgi/l/email-protection#bcd0d5deceddcec5fcd9dad8cfcf92d3cedb
# 29 / 221 done, working on https://www.vwml.org/about-us/what-we-do/news/13817-library-conference-2024-on-sale
# 30 / 222 done, working on https://www.vwml.org/support-us/join-us/starter-membership
# 31 / 223 done, working on https://www.vwml.org/vwml-digitised-resources
# 32 / 224 done, working on https://www.vwml.org/access-at-cecil-sharp-house
# 33 / 224 done, working on https://www.vwml.org/vwml-subject-guides/study-guides
# 34 / 225 done, working on https://www.vwml.org/vwml-catalogues-and-indexes/vwml-help
# 35 / 226 done, working on https://www.vwml.org/vwml-catalogues-and-indexes/vwml-help/vwml-map-help
# 36 / 227 done, working on https://www.vwml.org/basket
# 37 / 228 done, working on https://www.vwml.org/vwml-events/past-events/past-dance-conferences
# 38 / 229 done, working on https://www.vwml.org/safeguarding
# 39 / 230 done, working on https://www.vwml.org/booking-t-cs
# 40 / 230 done, working on https://www.vwml.org/vwml-support
# 41 / 231 done, working on https://www.vwml.org/vwml-about-us
# 42 / 232 done, working on https://www.vwml.org/about-us/publications/folk-music-journal
# 43 / 233 done, working on https://www.vwml.org/vwml-about-us/vwml-projects/past-projects
# 44 / 233 done, working on https://www.vwml.org/vwml-events/past-events/past-events-lectures
# 45 / 234 done, working on https://www.vwml.org/contact-us
# 46 / 235 done, working on https://www.vwml.org/vwml-events/past-events
# 47 / 236 done, working on https://www.vwml.org/vwml-digitised-resources/historic-dance-and-tune-books
# 48 / 237 done, working on https://www.vwml.org/about-us/what-we-do/news?filter_tag[0]=122
# 49 / 238 done, working on https://www.vwml.org/vwml-events/current-events/vwml-current-lectures
# 50 / 239 done, working on https://www.vwml.org/vwml-subject-guides/beginners-guide-dance
# 51 / 239 done, working on https://www.vwml.org/whats-on/61-conferences/13727-two-day-conference-collectomania-saturday
# 52 / 240 done, working on https://www.vwml.org/vwml-catalogues-and-indexes/vwml-help/roud-indexes-help
# 53 / 241 done, working on https://www.vwml.org/newsletter
# 54 / 241 done, working on https://www.vwml.org/cecil-sharp-house
# 55 / 241 done, working on https://www.vwml.org/vwml-events/past-events/past-events-broadside-days
# 56 / 242 done, working on https://www.vwml.org/vwml-subject-guides/beginners-guide-song
# 57 / 242 done, working on https://www.vwml.org/vwml-catalogues-and-indexes/vwml-help/archives-catalogue-help
# 58 / 242 done, working on https://www.vwml.org/vwml-events/past-events/past-song-conferences
# 59 / 243 done, working on https://www.vwml.org/vwml-about-us/vwml-projects/current-projects
# 60 / 244 done, working on https://www.vwml.org/calendar-events
# 61 / 245 done, working on https://www.vwml.org/vwml-catalogues-and-indexes/vwml-help/library-catalogue-help
# 62 / 246 done, working on https://www.vwml.org/vwml-subject-guides/beginners-guide-customs
# 63 / 247 done, working on https://www.vwml.org/vwml-subject-guides
# 64 / 248 done, working on https://www.vwml.org/support-us/folk-shop
# 65 / 249 done, working on https://www.vwml.org/vwml-about-us/publications
# 66 / 250 done, working on https://www.vwml.org/code-of-conduct
# 67 / 251 done, working on https://www.vwml.org/cdn-cgi/l/email-protection#fe92979c8c9f8c87be9b989a8d8dd0918c99
# 68 / 251 done, working on https://www.vwml.org/about-us/what-we-do
# 69 / 252 done, working on https://www.vwml.org/cdn-cgi/l/email-protection#fc90959e8e9d8e85bc999a988f8fd2938e9b
# 70 / 252 done, working on https://www.vwml.org/cdn-cgi/l/email-protection#e884818a9a899a91a88d8e8c9b9bc6879a8f
# 71 / 252 done, working on https://www.vwml.org/cdn-cgi/l/email-protection#016d6863736073784164676572722f6e7366
# 72 / 252 done, working on https://www.vwml.org/cdn-cgi/l/email-protection#3955505b4b584b40795c5f5d4a4a17564b5e
# 73 / 252 done, working on https://www.vwml.org/cdn-cgi/l/email-protection#234f4a415142515a6346454750500d4c5144
# 74 / 252 done, working on https://www.vwml.org/about-us/who-we-are/board
# 75 / 253 done, working on https://www.vwml.org/about-us/folk-player/old-songs-podcast
# 76 / 254 done, working on https://www.vwml.org/learning/family
# 77 / 254 done, working on https://www.vwml.org/images/present/Docs/Documentation/GeneralEmergencyEvacuationPlan.pdf
# 78 / 255 done, working on https://www.vwml.org/artist-development/partners/associate-artists
# 79 / 256 done, working on https://www.vwml.org/artist-development/at-cecil-sharp-house
# 80 / 257 done, working on https://www.vwml.org/about-us/who-we-are/president
# 81 / 257 done, working on https://www.vwml.org/learning/adults
# 82 / 258 done, working on https://www.vwml.org/support-us/gift-vouchers
# 83 / 259 done, working on https://www.vwml.org/about-us/what-we-do/appg-for-folk-arts
# 84 / 260 done, working on https://www.vwml.org/about-us/folk-player/young-folk-club-playlists
# 85 / 261 done, working on https://www.vwml.org/whats-on?subcat=28
# 86 / 262 done, working on https://www.vwml.org/learning/practitioners/folk-education-network
# 87 / 263 done, working on https://www.vwml.org/support-us/join-us/individuals
# 88 / 263 done, working on https://www.vwml.org/learning/adults/monday-folk-singers
# 89 / 264 done, working on https://www.vwml.org/learning
# 90 / 265 done, working on https://www.vwml.org/images/past/EFDSSASSETS/PDFs/EFDSS-Health-and-Safety-and-Access-Brief-2019.pdf
# 91 / 265 done, working on https://www.vwml.org/learning/practitioners/educators
# 92 / 266 done, working on https://www.vwml.org/learning/young-people
# 93 / 266 done, working on https://www.vwml.org/learning/resources
# 94 / 267 done, working on https://www.vwml.org/images/present/Docs/Forms/EFDSS-SafeguardingReportForm.doc
# 95 / 267 done, working on https://www.vwml.org/artist-development/artists/other-opportunities
# 96 / 267 done, working on https://www.vwml.org/artist-development/artists/musicians-in-museums
# 97 / 268 done, working on https://www.vwml.org/about-us/what-we-do/news
# 98 / 269 done, working on https://www.vwml.org/support-us/donate-now/leave-a-legacy
# 99 / 270 done, working on https://www.vwml.org/about-us/our-history/past-projects
# 100 / 271 done, working on https://www.vwml.org/learning/adults/csh-choir
# 101 / 272 done, working on https://www.vwml.org/support-us/donate-now/us-giving
# 102 / 272 done, working on https://www.vwml.org/learning/adults/classes-and-courses-faqs
# 103 / 273 done, working on https://www.vwml.org/about-us
# 104 / 273 done, working on https://www.vwml.org/artist-development/artists
# 105 / 273 done, working on https://www.vwml.org/artist-development/partners
# 106 / 274 done, working on https://www.vwml.org/learning/young-people/youth-ceilidhs
# 107 / 274 done, working on https://www.vwml.org/artist-development/folk-discovery
# 108 / 274 done, working on https://www.vwml.org/learning/adults/music-workshops
# 109 / 275 done, working on https://www.vwml.org/artist-development/partners/associate-company
# 110 / 276 done, working on https://www.vwml.org/about-us/work-for-us/work-experience
# 111 / 277 done, working on https://www.vwml.org/support-us/join-us/member-dance-clubs
# 112 / 277 done, working on https://www.vwml.org/learning/practitioners/dance-development
# 113 / 278 done, working on https://www.vwml.org/merchandise?Attribute_Website=EFDSS
# 114 / 279 done, working on https://www.vwml.org/about-us/work-for-us
# 115 / 279 done, working on https://www.vwml.org/learning/resources/glossary
# 116 / 280 done, working on https://www.vwml.org/learning/practitioners
# 117 / 281 done, working on https://www.vwml.org/artist-development/at-cecil-sharp-house/programming
# 118 / 282 done, working on https://www.vwml.org/images/present/Docs/Documentation/EFDSS-PolicyFacePainting.pdf
# 119 / 283 done, working on https://www.vwml.org/about-us/what-we-do/library
# 120 / 283 done, working on https://www.vwml.org/about-us/folk-player/in-the-archive-with
# 121 / 283 done, working on https://www.vwml.org/about-us/what-we-do/press-and-media
# 122 / 284 done, working on https://www.vwml.org/about-us/who-we-are/staff
# 123 / 285 done, working on https://www.vwml.org/learning/resources/a-z
# 124 / 286 done, working on https://www.vwml.org/images/present/Docs/Documentation/EFDSS-EDI-Policy.pdf
# 125 / 287 done, working on https://www.vwml.org/learning/adults/lectures-and-talks
# 126 / 288 done, working on https://www.vwml.org/whats-on/how-to-book/access
# 127 / 289 done, working on https://www.vwml.org/support-us/join-us/insurance
# 128 / 290 done, working on https://www.vwml.org/about-us/who-we-are
# 129 / 290 done, working on https://www.vwml.org/about-us/folk-player/listen-classic-folk
# 130 / 291 done, working on https://www.vwml.org/merchandise?Attribute_Website=CDs
# 131 / 292 done, working on https://www.vwml.org/about-us/our-history
# 132 / 292 done, working on https://www.vwml.org/about-us/publications/english-dance-and-song
# 133 / 292 done, working on https://www.vwml.org/support-us/campaigns
# 134 / 293 done, working on https://www.vwml.org/artist-development/partners/english-folk-expo
# 135 / 293 done, working on https://www.vwml.org/support-us/campaigns/library
# 136 / 294 done, working on https://www.vwml.org/artist-development/artists/commissions
# 137 / 295 done, working on https://www.vwml.org/support-us/donate-now/regular-donations
# 138 / 296 done, working on https://www.vwml.org/artist-development/at-cecil-sharp-house/exhibitions
# 139 / 297 done, working on https://www.vwml.org/policies?view=article&id=180:privacy-policy&catid=2
# 140 / 298 done, working on https://www.vwml.org/about-us/what-we-do/diversity
# 141 / 298 done, working on https://www.vwml.org/about-us/what-we-do/partner-organisations
# 142 / 298 done, working on https://www.vwml.org/artist-development/artists/bursary-stories
# 143 / 299 done, working on https://www.vwml.org/about-us/folk-player/folk-folk
# 144 / 300 done, working on https://www.vwml.org/support-us/campaigns/dance-development
# 145 / 300 done, working on https://www.vwml.org/support-us/campaigns/support-education
# 146 / 301 done, working on https://www.vwml.org/venue-hire/hire-our-venue
# 147 / 302 done, working on https://www.vwml.org/whats-on?subcat=66
# 148 / 303 done, working on https://www.vwml.org/support-us/donate-now
# 149 / 304 done, working on https://www.vwml.org/whats-on?subcat=26
# 150 / 304 done, working on https://www.vwml.org/images/present/Docs/Documentation/EFDSS-SafeguardingPolicy.pdf
# 151 / 305 done, working on https://www.vwml.org/whats-on?subcat=27
# 152 / 306 done, working on https://www.vwml.org/whats-on/how-to-book
# 153 / 307 done, working on https://www.vwml.org/whats-on/how-to-book/travel
# 154 / 308 done, working on https://www.vwml.org/learning/resources/beginners-guides
# 155 / 309 done, working on https://www.vwml.org/about-us/what-we-do/advocacy
# 156 / 309 done, working on https://www.vwml.org/about-us/publications
# 157 / 310 done, working on https://www.vwml.org/support-us/campaigns/national-youth-folk-ensemble
# 158 / 311 done, working on https://www.vwml.org/about-us/folk-player
# 159 / 311 done, working on https://www.vwml.org/whats-on
# 160 / 312 done, working on https://www.vwml.org/artist-development/artists/micro-grants-2
# 161 / 313 done, working on https://www.vwml.org/learning/schools-and-colleges
# 162 / 314 done, working on https://www.vwml.org/images/present/Docs/Forms/EFDSS-SafeguardingReportForm.pdf
# 163 / 315 done, working on https://www.vwml.org/learning/young-people/holiday-courses
# 164 / 316 done, working on https://www.vwml.org/support-us/join-us/libraries-and-institutions
# 165 / 317 done, working on https://www.vwml.org/artist-development
# 166 / 317 done, working on https://www.vwml.org/artist-development/artists/showcases
# 167 / 317 done, working on https://www.vwml.org/learning/young-people/inclusive-folk
# 168 / 318 done, working on https://www.vwml.org/artist-development/artists/bursaries
# 169 / 319 done, working on https://www.vwml.org/support-us/donate-now/general-donation
# 170 / 319 done, working on https://www.vwml.org/learning/family/barn-dances
# 171 / 320 done, working on https://www.vwml.org/support-us/campaigns/artist-development
# 172 / 321 done, working on https://www.vwml.org/learning/young-people/london-youth-folk-ensemble
# 173 / 322 done, working on https://www.vwml.org/support-us/join-us
# 174 / 322 done, working on https://www.vwml.org/about-us/work-for-us/volunteer
# 175 / 322 done, working on https://www.vwml.org/venue-hire
# 176 / 323 done, working on https://www.vwml.org/learning/family/family-friendly
# 177 / 323 done, working on https://www.vwml.org/about-us/who-we-are/annual-reviews
# 178 / 323 done, working on https://www.vwml.org/learning/adults/dance
# 179 / 323 done, working on https://www.vwml.org/learning/schools-and-colleges/arts-mark
# 180 / 324 done, working on https://www.vwml.org/whats-on?subcat=61
# 181 / 324 done, working on https://www.vwml.org/images/present/Docs/House/CecilSharpHouseRiskAssessmentApril2024.pdf
# 182 / 325 done, working on https://www.vwml.org/about-us/work-for-us/vacancies
# 183 / 325 done, working on https://www.vwml.org/support-us/join-us/groups
# 184 / 326 done, working on https://www.vwml.org/merchandise?Attribute_Website=Publications

# %%
import os
print(os.getcwd())
# Out:
# /Users/victoriachen/Documents/My Baby Thesis/webscrapping

# %%
print(os.path.abspath("web_scraping_data"))
# Out:
# /Users/victoriachen/Documents/My Baby Thesis/webscrapping/web_scraping_data
